# %%
import pandas as pd

df = pd.read_csv('../data/cleaned_sales_data.csv')
df.head()
# Out:
#    OrderID        Date   Product     Category Region  Sales  Quantity  \
# 0     1001  2024-01-01    Laptop  Electronics  South  50000         1
# 1     1002  2024-01-02     Mouse  Electronics  North    500         2
# 2     1003  2024-01-03  Keyboard  Electronics   West   1500         1
# 3     1004  2024-01-04     Chair    Furniture   East   7000         1
# 4     1005  2024-01-05     Table    Furniture  South  12000         1
#
#    Revenue_per_unit
# 0           50000.0
# 1             250.0
# 2            1500.0
# 3            7000.0
# 4           12000.0
